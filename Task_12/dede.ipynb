# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import io
import requests
from datetime import datetime as dt

# %%
df=pd.read_csv('dominos_data.csv')

# %%
# Convert the "order_delivered_at" column to a pandas datetime object
df["order_delivered_at"] = pd.to_datetime(df["order_delivered_at"])
df["order_placed_at"] = pd.to_datetime(df["order_placed_at"])

# %%
df['day_of_month']=df['order_delivered_at'].dt.dayofweek

# %%
df['day_of_month'].value_counts().sort_index().plot (kind='barh')
# Out:
# <Axes: >

# %%
df['day_of_month'].value_counts().sort_index().plot(kind="line")
# Out:
# <Axes: >

# %%
df['Day_of_Week'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
df['Day_of_Week'] = df['order_delivered_at'].dt.day_name()
